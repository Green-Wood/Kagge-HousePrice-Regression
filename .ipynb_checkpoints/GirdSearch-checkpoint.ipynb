# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import AdaBoostRegressor,  GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split, GridSearchCV, learning_curve
from sklearn.metrics import mean_squared_error
import xgboost as XGB
import lightgbm as LGB
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from jupyterthemes import jtplot
jtplot.style(grid=False)

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None, scoring='accuracy',
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    """Generate a simple plot of the test and training learning curve"""
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score" + scoring)
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes, scoring=scoring)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
def rmsle_cv(model):
    kf = KFold(KF, shuffle=True, random_state=7).get_n_splits(train_x)
    rmse = np.sqrt(-cross_val_score(model, train_x, train_y, 
                                    scoring="neg_mean_squared_error", cv=kf))
    return rmse

# %%
class StackingAverageModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, base_models, meta_model, n_folds=5):
        self.base_models = base_models
        self.meta_model = meta_model
        self.n_folds = n_folds

    def fit(self, X, y):
        self.base_models_ = [list() for x in self.base_models]
        self.meta_model_ = clone(self.meta_model)
        kfold = KFold(n_splits=self.n_folds, shuffle=True, random_state=7)

        out_of_fold_prediction = np.zeros((X.shape[0], len(self.base_models)))
        for i, model in enumerate(self.base_models):
            for train_index, holdout_index in kfold.split(X, y):
                instance = clone(model)
                self.base_models_[i].append(instance)
                instance.fit(X[train_index], y[train_index])
                y_pred = instance.predict(X[holdout_index])
                out_of_fold_prediction[holdout_index, i] = y_pred

        self.meta_model.fit(out_of_fold_prediction, y)
        return self

    def predict(self, X):
        meta_features = np.column_stack([
            np.column_stack([model.predict(X) for model in base_models]).mean(axis=1)
            for base_models in self.base_models_
        ])
        return self.meta_model.predict(meta_features)
    

class PolynomialModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, models, proportions=[0.7, 0.15, 0.15]):
        self.models = models
        self.proportions = proportions

    def fit(self, train_x, train_y):
        self.models_ = [clone(x) for x in self.models]
        self.proportions_ = [x for x in self.proportions]

        for model in self.models_:
            model.fit(train_x, train_y)
        return self

    def predict(self, X):
        predictions = np.column_stack([
            model.predict(X)*self.proportions_[i] for i, model in enumerate(self.models_)
        ])
        return np.sum(predictions, axis=1)

# %%
train_x = pd.read_csv('./Data/train_x.csv').values
train_y = pd.read_csv('./Data/train_y.csv').values.ravel()
test_x = pd.read_csv('./Data/test_x.csv').values
KF = 5

# %%
svr = SVR(C=0.5, gamma=0.001, kernel='poly')
lasso = make_pipeline(RobustScaler(), Lasso(alpha=0.0005, random_state=7))
ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=0.9, random_state=7))
KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10,
                                   loss='huber', random_state=7)
xgb = XGB.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468,
                             learning_rate=0.05, max_depth=3,
                             n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=True,
                             random_state=7, nthread=-1)
lgb = LGB.LGBMRegressor(objective='regression', num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin=55, bagging_fraction=0.8,
                              bagging_freq=5, feature_fraction=0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf=6, min_sum_hessian_in_leaf=11)
stacking_model = StackingAverageModels(
    base_models=(GBoost, ENet, KRR), 
    meta_model=lasso)
poly_model = PolynomialModels(models=(stacking_model, xgb, lgb), proportions=[0.7, 0.15, 0.15])
final_model = StackingAverageModels(
    base_models=(xgb, lgb, stacking_model), 
    meta_model=ENet)

# %%
grid = GridSearchCV(estimator=PolynomialModels(models=(stacking_model, xgb, lgb)), param_grid={
    'proportions': [[0.7, 0.15, 0.15], [0.5, 0.25, 0.25], [0.3, 0.4, 0.3], [0.3, 0.3, 0.4]],
}, cv=KF, scoring='neg_mean_squared_error', n_jobs=2)

# %%
grid.fit(train_x, train_y)

# %%
grid.best_param_

# %%
grid.best_score_
# Out:
# -0.014166291152196185

# %%
plot_learning_curve(svr, 'SVR curve', train_x, train_y, 
                    cv=KF, scoring='neg_mean_squared_error')
# Out:
# <module 'matplotlib.pyplot' from 'c:\\users\\10275\\anaconda3\\envs\\ml\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plot_learning_curve(lasso, 'Lasso curve', train_x, train_y, 
                    cv=KF, scoring='neg_mean_squared_error')
# Out:
# <module 'matplotlib.pyplot' from 'c:\\users\\10275\\anaconda3\\envs\\ml\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plot_learning_curve(ENet, 'ENet curve', train_x, train_y.values.ravel(), 
                    cv=KF, scoring='neg_mean_squared_error')
# Out:
# <module 'matplotlib.pyplot' from 'c:\\users\\10275\\anaconda3\\envs\\ml\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plot_learning_curve(KRR, 'KRR curve', train_x, train_y, 
                    cv=KF, scoring='neg_mean_squared_error')
# Out:
# <module 'matplotlib.pyplot' from 'c:\\users\\10275\\anaconda3\\envs\\ml\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plot_learning_curve(GBoost, 'GBoost curve', train_x, train_y, 
                    cv=KF, scoring='neg_mean_squared_error')
# Out:
# <module 'matplotlib.pyplot' from 'c:\\users\\10275\\anaconda3\\envs\\ml\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plot_learning_curve(xgb, 'XGB curve', train_x, train_y, 
                    cv=KF, scoring='neg_mean_squared_error')
# Out:
# <module 'matplotlib.pyplot' from 'c:\\users\\10275\\anaconda3\\envs\\ml\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plot_learning_curve(lgb, 'LGB curve', train_x, train_y, 
                    cv=KF, scoring='neg_mean_squared_error')
# Out:
# <module 'matplotlib.pyplot' from 'c:\\users\\10275\\anaconda3\\envs\\ml\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
plot_learning_curve(stacking_model, 'Stacking', train_x, train_y,
                   cv=KF, scoring='neg_mean_squared_error')
# Out:
# c:\users\10275\anaconda3\envs\ml\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# c:\users\10275\anaconda3\envs\ml\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# c:\users\10275\anaconda3\envs\ml\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %%
plot_learning_curve(poly_model, 'Polynomial', train_x, train_y,
                   cv=KF, scoring='neg_mean_squared_error')
# Out:
# c:\users\10275\anaconda3\envs\ml\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# c:\users\10275\anaconda3\envs\ml\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# c:\users\10275\anaconda3\envs\ml\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %%
plot_learning_curve(final_model, 'final 2 layers', train_x, train_y,
                   cv=KF, scoring='neg_mean_squared_error')
# Out:
# c:\users\10275\anaconda3\envs\ml\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# c:\users\10275\anaconda3\envs\ml\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# c:\users\10275\anaconda3\envs\ml\lib\site-packages\sklearn\linear_model\coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %%
score = rmsle_cv(final_model)
print('{:.4f} ({:.4f})'.format(score.mean(), score.std()))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-ef68f1ca512e> in <module>()
# ----> 1 score = rmsle_cv(final_model)
#       2 print('{:.4f} ({:.4f})'.format(score.mean(), score.std()))
#
# <ipython-input-4-d5b1ad2d6b9e> in rmsle_cv(model)
#       2     kf = KFold(KF, shuffle=True, random_state=7).get_n_splits(train_x)
#       3     rmse = np.sqrt(-cross_val_score(model, train_x, train_y,
# ----> 4                                     scoring="neg_mean_squared_error", cv=kf))
#       5     return rmse
#
# c:\users\10275\anaconda3\envs\ml\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     340                                 n_jobs=n_jobs, verbose=verbose,
#     341                                 fit_params=fit_params,
# ...

# %% [markdown]
# |baseModel|metaModel|mse|std|
# |--|--|--|--|
# |KRR ENet GBoost|lasso|0.1085|0.0076|
# |KRR ENet GBoost SVR|lasso|0.1086|0.0074|
# |KRR ENet GBoost XGB|lasso|0.1084|0.0073|
# |lgb GBoost xgb KRR lasso|ENet|0.1085|0.0072|
# |KRR lasso GBoost|ENet|0.1085|0.0075|
# |stacking xgb lgb|ENet|0.1082|0.0070|
# |poly_model|None|0.1084|0.0071|

# %% [markdown]
# |models|proportions|mse|std|
# |-|-|-|-|
# |stacking, xgb, lgb|0.7, 0.15, 0.15|0.1084|0.0071|

# %%
stacking_model.fit(train_x, train_y)
test_stacking = pd.Series(np.expm1(stacking_model.predict(test_x)), name='Stacking')

# %%
lasso.fit(train_x, train_y)
KRR.fit(train_x, train_y)
ENet.fit(train_x, train_y)
GBoost.fit(train_x, train_y)
xgb.fit(train_x, train_y)
lgb.fit(train_x, train_y)

test_lasso = pd.Series(np.expm1(lasso.predict(test_x)), name='Lasso')
test_KRR = pd.Series(np.expm1(KRR.predict(test_x)), name='KRR')
test_ENet = pd.Series(np.expm1(ENet.predict(test_x)), name='ENet')
test_GBoost = pd.Series(np.expm1(GBoost.predict(test_x)), name='GBoost')
test_xgb = pd.Series(np.expm1(xgb.predict(test_x)), name='XGB')
test_lgb = pd.Series(np.expm1(lgb.predict(test_x)), name='LGB')


result = pd.concat([test_lasso, test_KRR,
                    test_ENet, test_GBoost, test_xgb, test_lgb, test_stacking], axis=1)
sns.heatmap(result.corr(), annot=True, cmap='RdYlGn', 
            linewidths=0.2, annot_kws={'size': 10})

# %%
# Out:
# array([0.00566251, 0.01698754, 0.06851642, 0.        , 0.00056625,
#        0.00736127, 0.00056625, 0.06908267, 0.04360136, 0.03793884,
#        0.02208381, 0.00566251, 0.00283126, 0.00339751, 0.00226501,
#        0.0011325 , 0.01359003, 0.00906002, 0.03114383, 0.        ,
#        0.0011325 , 0.02265006, 0.03567384, 0.01075878, 0.00962627,
#        0.04473386, 0.01472254, 0.        , 0.07870895, 0.00622877,
#        0.        , 0.00396376, 0.00509626, 0.00169875, 0.00339751,
#        0.00736127, 0.00679502, 0.01359003, 0.01302378, 0.00226501,
#        0.02661382, 0.00792752, 0.00226501, 0.03114383, 0.00453001,
#        0.00453001, 0.00283126, 0.0186863 , 0.0186863 , 0.01075878,
#        0.        , 0.00849377, 0.        , 0.        , 0.00622877,
#        0.        , 0.01245753, 0.00962627, 0.03001132, 0.01245753,
#        0.0011325 , 0.        , 0.00169875, 0.00453001, 0.00056625,
#        0.        , 0.        , 0.00056625, 0.00056625, 0.00283126,
# ...

# %%
test_x = pd.read_csv('./Data/test_x.csv')

model_name = 'final model(2 layer)'
model = final_model

model.fit(train_x, train_y)
test_y = model.predict(test_x.values)
test_y = np.expm1(test_y)
test_y = pd.DataFrame(test_y, columns=['SalePrice'])

submission = pd.concat([pd.read_csv('./Data/test.csv')['Id'], test_y], axis=1)
submission.to_csv('./Predictions/{}.csv'.format(model_name), index=False)
sns.distplot(submission['SalePrice'])
