# %%
1 + 2
# Out:
# 3

# %%
import pandas as pd
import math

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {i: np.random.randn() for i in range(7)}

# %%
data
# Out:
# {0: 1.8267177878050957,
#  1: -0.829053607513052,
#  2: 0.6328242123521561,
#  3: 0.2973123791740751,
#  4: 0.5101014775010057,
#  5: 0.4686069616385237,
#  6: -0.9373192978235458}

# %%
pd.read_csv('./Data/train.csv')
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
train = pd.read_csv('./Data/train.csv')

# %%
train.shape
# Out:
# (1460, 81)

# %%
test = pd.read_csv('./Data/test.csv')
test.shape
# Out:
# (1459, 80)

# %%
train?

# %%
plt.plot(np.random.randn(50))

# %%
def isPrime(num):
    for i in range(2, num):
        if i * i > num:
            return True
        if num % i == 0:
            return False
    return True

# %%
isPrime(2760889966649)
# Out:
# True

# %%
isPrime(2760889966651)
# Out:
# True

# %%
food_list = ['burger', 'apple', 'beef', 'baccon']
mapping = {}
for i, v in enumerate(food_list):
    mapping[v] = i
mapping
# Out:
# {'burger': 0, 'apple': 1, 'beef': 2, 'baccon': 3}

# %%
mapping['beef']
# Out:
# 2

# %%
strings = ['a', 'as', 'bat', 'car', 'dove', 'python']

# %%
[x.upper() for x in strings if len(x) >= 2]
# Out:
# ['AS', 'BAT', 'CAR', 'DOVE', 'PYTHON']

# %%
[len(x) for x in strings]
# Out:
# [1, 2, 3, 3, 4, 6]

# %%
array = ['aaa', 'abc', 'aab', 'accdf', 'aasda']

# %%
array
# Out:
# ['aaa', 'abc', 'aab', 'accdf', 'aasda']

# %%
array.sort(key=(lambda x: len(set(list(x)))))

# %%
array
# Out:
# ['aaa', 'aab', 'abc', 'aasda', 'accdf']

# %%
points = np.arange(-5, 5, 0.01)

# %%
xs, ys = np.meshgrid(points, points)

# %%
ys
# Out:
# array([[-5.  , -5.  , -5.  , ..., -5.  , -5.  , -5.  ],
#        [-4.99, -4.99, -4.99, ..., -4.99, -4.99, -4.99],
#        [-4.98, -4.98, -4.98, ..., -4.98, -4.98, -4.98],
#        ...,
#        [ 4.97,  4.97,  4.97, ...,  4.97,  4.97,  4.97],
#        [ 4.98,  4.98,  4.98, ...,  4.98,  4.98,  4.98],
#        [ 4.99,  4.99,  4.99, ...,  4.99,  4.99,  4.99]])

# %%
xs
# Out:
# array([[-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        ...,
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99],
#        [-5.  , -4.99, -4.98, ...,  4.97,  4.98,  4.99]])

# %%
z = np.sqrt(xs**2+ ys**2)

# %%
z
# Out:
# array([[7.07106781, 7.06400028, 7.05693985, ..., 7.04988652, 7.05693985,
#         7.06400028],
#        [7.06400028, 7.05692568, 7.04985815, ..., 7.04279774, 7.04985815,
#         7.05692568],
#        [7.05693985, 7.04985815, 7.04278354, ..., 7.03571603, 7.04278354,
#         7.04985815],
#        ...,
#        [7.04988652, 7.04279774, 7.03571603, ..., 7.0286414 , 7.03571603,
#         7.04279774],
#        [7.05693985, 7.04985815, 7.04278354, ..., 7.03571603, 7.04278354,
#         7.04985815],
#        [7.06400028, 7.05692568, 7.04985815, ..., 7.04279774, 7.04985815,
#         7.05692568]])

# %%
plt.title('Image plot of $\sqrt{x^2+y^2}$ for a grid of values')
plt.imshow(z, cmap=plt.cm.gray)
plt.colorbar()

# %%
xarr =  np.array([1, 2, 3, 4, 5, 6])
yarr = np.array([-1, -2, -3, -4, -5, -6])
cond = np.array([True, True, False, False, True, False])

# %%
res = np.where(cond, xarr, yarr)

# %%
res
# Out:
# array([ 1,  2, -3, -4,  5, -6])

# %%
cond = cond.reshape(2, -1)
res = np.where(cond, 2, -2)

# %%
res
# Out:
# array([[ 2,  2, -2],
#        [-2,  2, -2]])

# %%
arr = np.array([[2, 2], [-1, -1]])

# %%
arr
# Out:
# array([[ 2,  2],
#        [-1, -1]])

# %% [markdown]
# ### - axis=0表示在竖轴，即对于每一列逐行进行操作
# ### - axis=1表示在横轴，即对于每一行逐列进行操作

# %%
arr.sum(axis=0)
# Out:
# array([1, 1])

# %%
arr.sum(axis=1)
# Out:
# array([ 4, -2])

# %%
arr.cumsum()
# Out:
# array([2, 4, 3, 2], dtype=int32)

# %%
arr.cumsum(axis=1)
# Out:
# array([[ 2,  4],
#        [-1, -2]], dtype=int32)

# %%
arr.cumsum(axis=0)
# Out:
# array([[2, 2],
#        [1, 1]], dtype=int32)

# %%
plt.plot(np.random.uniform(size=(4, 4), low=-10, high=10))

# %%
math.pi
# Out:
# 3.141592653589793
